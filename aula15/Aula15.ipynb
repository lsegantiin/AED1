# %%
def animais(cabecas, pes):
    coelhos = (pes - 2 * cabecas) // 2
    patos = cabecas - coelhos
    return patos, coelhos

cabecas = int(input("Digite o total de cabeças: "))
pes = int(input("Digite o total de pés: "))

patos, coelhos = calcular_animais(cabecas, pes)

print("Total de Patos:", patos)
print("Total de Coelhos:", coelhos)
# Out:
# Digite o total de cabeças:  38
# Digite o total de pés:  114
# Total de Patos: 19
# Total de Coelhos: 19

# %%
ra = "3011542613038"

soma = 0
multiplicacao = 1

for digito in ra:
    numero = int(digito)
    soma += numero
    multiplicacao *= numero

print("RA =", ra)
print("Multiplicação =", multiplicacao)
print("Soma =", soma)
# Out:
# RA = 3011542613038
# Multiplicação = 0
# Soma = 37

# %%
def reverso(numero):
    return str(numero)[::-1]
    
ra = 3011542613038

resultado = reverso(ra)

print("Número original:", ra)
print("Número reverso:", resultado)
# Out:
# Número original: 3011542613038
# Número reverso: 8303162451103
