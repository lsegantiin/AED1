# %%
idade = int(input("Qual sua idade: "))
if idade >= 18:
    print("Pode dirigir!")
else: 
    print("Chama o Uber!")
# Out:
# Qual sua idade:  26
# Pode dirigir!

# %%
idade = int(input("Qual sua idade: "))
carro = input("Tem Carro? <S/N>")
if idade >= 18:
    if carro == "S":
        print("Pode dirigir!")
    else:
        print("Chama o Uber!")
else:
    print("Chama o Uber!")
# Out:
# Qual sua idade:  18
# Tem Carro? <S/N> S
# Pode dirigir!

# %%
idade = int(input("Qual sua idade: "))
carro = input("Tem Carro? <S/N>")
if (idade >= 18) and (carro == "S"):
    print("Pode dirigir!")
else:
    print("Chama o Uber!")
# Out:
# Qual sua idade:  18
# Tem Carro? <S/N> N
# Chama o Uber!

# %%
idade = int(input("Qual sua idade: "))
if idade >= 18:
    carro = input("Tem carro? <S/N> ")
    if carro == "S":
        print("Pode dirigir!")
    else:
        print("Chama o uber!")
else:
    print("Chama o Uber!")
# Out:
# Qual sua idade:  18
# Tem carro? <S/N>  S
# Pode dirigir!

# %%
nota1 = float(input("Qual a sua nota1: "))
nota2 = float(input("Qual a sua nota2: "))
media = (nota1 + nota2) / 2
print("Sua média é: ", media)
if media >= 5:
    print("Aprovado!")
else:
    print("Reprovado")
# Out:
# Qual a sua nota1:  10
# Qual a sua nota2:  1
# Sua média é:  5.5
# Aprovado!

# %%
nota1 = float(input("Qual a sua nota1?: "))
if nota1 >= 7:
    nota1 = nota1 + 0.5
nota2 = float(input("Qual a sua nota2?: "))
if nota2 >= 7:
    nota2 = nota2 + 0.5
media = (nota1 + nota2) / 2
print("Sua média é: ", media)
if media >= 5:
    print("Aprovado!")
else:
    print("Reprovado")
# Out:
# Qual a sua nota1?:  8
# Qual a sua nota2?:  8
# Sua média é:  8.5
# Aprovado!

# %%
nota1 = float(input("Qual a sua nota1?: "))
if nota1 >= 7:
    nota1 = nota1 + 0.5
print("Voce ganhou 0,5 pontos, sua nova nota é ", nota1)
nota2 = float(input("Qual a sua nota2?: "))
if nota2 >= 7:
    nota2 = nota2 + 0.5
print("Voce ganhou 0,5 pontos, sua nova nota é: ", nota2)
media = (nota1 + nota2) / 2
print("Sua média é: ", media)
if media >= 5:
    print("Aprovado!")
else:
    print("Reprovado")
# Out:
# Qual a sua nota1?:  3
# Voce ganhou 0,5 pontos, sua nova nota é  3.0
# Qual a sua nota2?:  7
# Voce ganhou 0,5 pontos, sua nova nota é:  7.5
# Sua média é:  5.25
# Aprovado!

# %%
print("Digite os lados de um triangulo: ")
a = float(input( "Qual o seu a?: "))
b = float(input( "Qual o seu b?: "))
c = float(input( "Qual o seu c?: "))
if (a >= b+c) or (b >= a+c) or (c >= a+b):
    print("Não é um Triangulo")
else:
    if (a == b == c):
        print("Triangulo Equilátero")
    elif (a == b) or (b == c) or (a==c):
        print("Triangulo Isóceles")
    else:
        print("Triangulo Escaleno")
# Out:
# Digite os lados de um triangulo:
# Qual o seu a?:  3
# Qual o seu b?:  3
# Qual o seu c?:  3
# Triangulo Equilátero

# %%
print("Digite os lados de um triangulo: ")
a = float(input( "Qual o seu a?: "))
b = float(input( "Qual o seu b?: "))
c = float(input( "Qual o seu c?: "))
if (a+b > c) and (b+c > a) and (a+c > b):
    if (a == b == c):
        print("Triangulo Equilátero")
    elif (a == b) or (b == c) or (a == c):
        print("Triangulo Isóceles")
    else:
        print("Triangulo Escaleno")
else: 
    print("não é um triangulo")
# Out:
# Digite os lados de um triangulo:
# Qual o seu a?:  3
# Qual o seu b?:  3
# Qual o seu c?:  3
# Triangulo Equilátero
