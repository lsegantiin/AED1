# %%
numero = int(input("Digite um número inteiro: "))

if numero % 5 == 0 and numero % 3 == 0:
    print("É divisível por 5 e por 3 .")
else:
    print("NÃO é divisível por 5 e por 3.")
# Out:
# Digite um número inteiro:  30
# É divisível por 5 e por 3 .

# %%
valor = float(input("Digite o valor da compra: R$ "))

if valor <= 1000:
    desconto = valor * 0.10
elif valor <= 5000:
    desconto = valor * 0.20
else:
    desconto = valor * 0.30

valor_final = valor - desconto

print("Desconto: R$", desconto)
print("Valor final: R$", valor_final)
# Out:
# Digite o valor da compra: R$  1000
# Desconto: R$ 100.0
# Valor final: R$ 900.0

# %%
largura = float(input("Digite a largura do aposento (m): "))
comprimento = float(input("Digite o comprimento do aposento (m): "))
litros_lata = float(input("Quantos litros tem cada lata de tinta: "))

altura = 2.80
porta = 0.80 * 2.10
cobertura_por_litro = 3
