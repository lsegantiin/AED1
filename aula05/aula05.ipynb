# %% [markdown]
# Cálculo da aréa

# %%
base = float(input("Digite a base: "))
altura = float(input("Digite a Altura: "))
area = base * altura
print("Altura do quadrilátero é: ", area)
# Out:
# Digite a base:  4.7
# Digite a Altura:  5.2
# Altura do quadrilátero é:  24.44
